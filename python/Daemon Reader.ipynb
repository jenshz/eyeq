# %%
import matplotlib.pyplot as plt
from eyeq import Client, Block, block
client = Client("tcp://localhost:13450")

# %%
client.list_stores()
# Out:
# stores {
#   name: "SAMPLES"
#   block_count: 15000
#   block_offset: 1442
# }
# stores {
#   name: "WOD"
#   block_count: 8640
# }

# %%
data = client.read_complex_samples("SAMPLES", 0, 20000)

# %%
plt.psd(data);
